# %%
import pandas as pd

# %%
df = pd.read_csv('StudentPerformance.csv')

# %%
df
# Out:
#     math_score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0         73.0           78.0           79.0             79.0            2026
# 1         64.0           75.0           66.0             75.0            2022
# 2         61.0           92.0           76.0             89.0            2025
# 3         73.0           91.0           69.0             93.0            2021
# 4         66.0           95.0           61.0             98.0            2020
# 5         72.0           87.0           67.0             80.0            2026
# 6         69.0           76.0           71.0             76.0            2018
# 7         71.0           89.0           79.0             76.0            2024
# 8         80.0           89.0            NaN             83.0            2021
# 9         66.0           87.0            NaN             91.0            2024
# 10       100.0           82.0           75.0             80.0            2020
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     math_score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0         73.0           78.0           79.0             79.0            2026
# 1         64.0           75.0           66.0             75.0            2022
# 2         61.0           92.0           76.0             89.0            2025
# 3         73.0           91.0           69.0             93.0            2021
# 4         66.0           95.0           61.0             98.0            2020
# 5         72.0           87.0           67.0             80.0            2026
# 6         69.0           76.0           71.0             76.0            2018
# 7         71.0           89.0           79.0             76.0            2024
# 8         80.0           89.0            NaN             83.0            2021
# 9         66.0           87.0            NaN             91.0            2024
# 10       100.0           82.0           75.0             80.0            2020
# ...

# %%
df.isnull().sum()
# Out:
# math_score         3
# Reading_Score      1
# Writing_Score      5
# Placement_Score    3
# Club_join_date     0
# Placement_offer    0
# dtype: int64

# %%
df.describe()
# Out:
#        math_score  Reading_Score  Writing_Score  Placement_Score  \
# count   46.000000      48.000000      44.000000        46.000000
# mean    69.456522      83.854167      73.795455        86.586957
# std     12.419888       6.154015      20.346509         8.280032
# min      5.000000      75.000000      60.000000        75.000000
# 25%     64.000000      78.000000      66.000000        80.000000
# 50%     71.500000      84.000000      71.000000        86.500000
# 75%     76.000000      89.000000      77.000000        94.500000
# max    100.000000      95.000000     200.000000       100.000000
#
#        Club_join_date  Placement_offer
# count       49.000000        49.000000
# mean      2022.204082         2.326531
# std          2.661293         1.637933
# min       2018.000000         1.000000
# 25%       2020.000000         2.000000
# 50%       2022.000000         2.000000
# 75%       2025.000000         2.000000
# max       2026.000000        10.000000

# %%
x=df.math_score.mean()

# %%
x
# Out:
# np.float64(69.45652173913044)

# %%
df['math_score'].fillna(x, inplace=True)
# Out:
# C:\Users\System05\AppData\Local\Temp\ipykernel_9912\466351362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math_score'].fillna(x, inplace=True)

# %%
df
# Out:
#     math_score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0    73.000000           78.0           79.0             79.0            2026
# 1    64.000000           75.0           66.0             75.0            2022
# 2    61.000000           92.0           76.0             89.0            2025
# 3    73.000000           91.0           69.0             93.0            2021
# 4    66.000000           95.0           61.0             98.0            2020
# 5    72.000000           87.0           67.0             80.0            2026
# 6    69.000000           76.0           71.0             76.0            2018
# 7    71.000000           89.0           79.0             76.0            2024
# 8    80.000000           89.0            NaN             83.0            2021
# 9    66.000000           87.0            NaN             91.0            2024
# 10  100.000000           82.0           75.0             80.0            2020
# ...

# %%
df.isnull().sum()
# Out:
# math_score         0
# Reading_Score      1
# Writing_Score      5
# Placement_Score    3
# Club_join_date     0
# Placement_offer    0
# dtype: int64

# %%
y=df.Writing_Score.mode()

# %%
df.Writing_Score.fillna(y, inplace="True")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df.Writing_Score.fillna(y, inplace="True")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:7289, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7164 @final
#    7165 @doc(
#    7166     klass=_shared_doc_kwargs["klass"],
#    (...)   7177     downcast: dict | None | lib.NoDefault = lib.no_default,
#    7178 ) -> Self | None:
#    7179     """
#    7180     Fill NA/NaN values using the specified method.
#    7181
#    (...)   7287     Note that column D is not affected since it is not present in df2.
#    7288     """
# -> 7289     inplace = validate_bool_kwarg(inplace, "inplace")
#    7290     if inplace:
#    7291         if not PYPY and not WARNING_CHECK_DISABLED and using_copy_on_write():
#
# ...

# %%
df.Writing_Score.fillna(y, inplace=True)

# %%
df
# Out:
#     math_score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0    73.000000           78.0           79.0             79.0            2026
# 1    64.000000           75.0           66.0             75.0            2022
# 2    61.000000           92.0           76.0             89.0            2025
# 3    73.000000           91.0           69.0             93.0            2021
# 4    66.000000           95.0           61.0             98.0            2020
# 5    72.000000           87.0           67.0             80.0            2026
# 6    69.000000           76.0           71.0             76.0            2018
# 7    71.000000           89.0           79.0             76.0            2024
# 8    80.000000           89.0            NaN             83.0            2021
# 9    66.000000           87.0            NaN             91.0            2024
# 10  100.000000           82.0           75.0             80.0            2020
# ...

# %%
df.isnull().sum()
# Out:
# math_score         0
# Reading_Score      1
# Writing_Score      5
# Placement_Score    3
# Club_join_date     0
# Placement_offer    0
# dtype: int64

# %%
df['Writing_Score'].fillna(x, inplace=True)

# %%
df.isnull().sum()
# Out:
# math_score         0
# Reading_Score      1
# Writing_Score      0
# Placement_Score    3
# Club_join_date     0
# Placement_offer    0
# dtype: int64

# %%
df.Placement_Score.fillna(y, inplace=True)
# Out:
# C:\Users\System05\AppData\Local\Temp\ipykernel_9912\4006744590.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Score.fillna(y, inplace=True)

# %%
y=df.Placement_Score.min()

# %%
df.Placement_Score.fillna(y, inplace=True)
# Out:
# C:\Users\System05\AppData\Local\Temp\ipykernel_9912\4006744590.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Score.fillna(y, inplace=True)

# %%
df['Placement_Score'].fillna(x, inplace=True)
# Out:
# C:\Users\System05\AppData\Local\Temp\ipykernel_9912\1159464953.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Placement_Score'].fillna(x, inplace=True)

# %%
df
# Out:
#     math_score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0    73.000000           78.0      79.000000             79.0            2026
# 1    64.000000           75.0      66.000000             75.0            2022
# 2    61.000000           92.0      76.000000             89.0            2025
# 3    73.000000           91.0      69.000000             93.0            2021
# 4    66.000000           95.0      61.000000             98.0            2020
# 5    72.000000           87.0      67.000000             80.0            2026
# 6    69.000000           76.0      71.000000             76.0            2018
# 7    71.000000           89.0      79.000000             76.0            2024
# 8    80.000000           89.0      69.456522             83.0            2021
# 9    66.000000           87.0      69.456522             91.0            2024
# 10  100.000000           82.0      75.000000             80.0            2020
# ...

# %%
df.isnull().sum()
# Out:
# math_score         0
# Reading_Score      1
# Writing_Score      0
# Placement_Score    0
# Club_join_date     0
# Placement_offer    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['math_score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_join_date', 'Placement_offer'],
#       dtype='object')

# %%
col=['math_score', 'Writing_Score', 'Placement_Score',
        'Placement_offer']

# %%
df[['math_score', 'Writing_Score', 'Placement_Score', 'Placement_offer']].boxplot()
# Out:
# <Axes: >

# %%
df.Placement_offer>100
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# Name: Placement_offer, dtype: bool

# %%
df.boxplot(['math_score', 'Writing_Score', 'Placement_Score', 'Placement_offer'])
# Out:
# <Axes: >

# %%
df.boxplot(['math_score', 'Writing_Score', 'Placement_Score', 'Placement_offer'])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.show()
